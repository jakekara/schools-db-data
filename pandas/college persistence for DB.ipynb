# %%
import pandas as pd, re
import numpy as np
import getschools as gs

# %%
def get_df(group):
    
    ret = pd.read_csv("../clean/csv/collegeEntrancePersistence-"+group+".csv")
    
    
    for c in [u'2009_10_entrance_pct','2009_10_persistence_pct',
       u'2010_11_entrance_pct', u'2010_11_persistence_pct',
       u'2011_12_entrance_pct', u'2011_12_persistence_pct',
       u'2012_13_entrance_pct', u'2012_13_persistence_pct',
       u'2013_14_entrance_pct', u'2013_14_persistence_pct']:
        
        ret[c] = pd.to_numeric(ret[c],errors="coerce")

    ret["school_code"] = ret["school_code"].astype(str).str.zfill(7)
    ret["district_code"] = ret["district_code"].astype(str).str.zfill(7)

    ret = gs.add_drg(ret)
    
    def four_year(row):
        non_nulls = 0
        avgs = []
        for c in ['2009_10_persistence_pct',
                  '2010_11_persistence_pct',
                  '2011_12_persistence_pct',
                  '2012_13_persistence_pct',
                  '2013_14_persistence_pct']:
            
            if row[c] is None: 
                continue
                
            non_nulls += 1
            avgs += [row[c]]
                
        if len(avgs) == 0 or non_nulls == 0:
            return None
        
        return np.nanmedian(avgs)
                
    ret["four_y_percent"] = ret.apply(four_year,axis=1)        
    
    ret = ret[ret["four_y_percent"].notnull()]
    return ret

get_df("all")
# Out:
#                                      district district_code  \
# 185                    Weston School District       1570011
# 30                     Darien School District       0350011
# 188                    Wilton School District       1610011
# 186                  Westport School District       1580011
# 80                    Madison School District       0760011
# 139                Ridgefield School District       1180011
# 99                 New Canaan School District       0900011
# 36              East Hartford School District       0430011
# 51                Glastonbury School District       0540011
# 204               Regional School District 08       2080012
# 22                   Cheshire School District       0250011
# 1                        Avon School District       0040011
# 144                  Simsbury School District       1280011
# 48                  Fairfield School District       0510011
# 206               Regional School District 09       2090012
# 197               Regional School District 05       2050012
# 49                  Fairfield School District       0510011
# 211               Regional School District 13       2130012
# 145                    Somers School District       1290011
# 57                   Guilford School District       0600011
# 130              Old Saybrook School District       1060011
# 213               Regional School District 15       2150012
# 50                 Farmington School District       0520011
# 118                   Newtown School District       0970011
# 120            North Branford School District       0990011
# 163                  Trumbull School District       1440011
# 2                      Berlin School District       0070011
# 8                      Bolton School District       0120011
# 54                  Greenwich School District       0570011
# 151                  Stamford School District       1350011
# ..                                        ...           ...
# 270  Connecticut Technical High School System       9000016
# 132                Plainfield School District       1090011
# 104                 New Haven School District       0930011
# 220          Capitol Region Education Council       2410014
# 274  Connecticut Technical High School System       9000016
# 68                   Hartford School District       0640011
# 64                   Hartford School District       0640011
# 66                   Hartford School District       0640011
# 112                 New Haven School District       0930011
# 74                   Hartford School District       0640011
# 115                New London School District       0950011
# 272  Connecticut Technical High School System       9000016
# 59                   Hartford School District       0640011
# 261  Connecticut Technical High School System       9000016
# 175                 Waterbury School District       1510011
# 266  Connecticut Technical High School System       9000016
# 10                 Bridgeport School District       0150011
# 243        Common Ground High School District       2680013
# 271  Connecticut Technical High School System       9000016
# 69                   Hartford School District       0640011
# 268  Connecticut Technical High School System       9000016
# 264  Connecticut Technical High School System       9000016
# 65                   Hartford School District       0640011
# 265  Connecticut Technical High School System       9000016
# 106                 New Haven School District       0930011
# 227          Capitol Region Education Council       2410014
# 62                   Hartford School District       0640011
# 285                                     Learn       2450014
# 263  Connecticut Technical High School System       9000016
# 38              East Hartford School District       0430011
#
#                                                 school school_code  \
# 185                                 Weston High School     1576111
# 30                                  Darien High School     0356111
# 188                                 Wilton High School     1616111
# 186                                Staples High School     1586111
# 80                             Daniel Hand High School     0766111
# 139                             Ridgefield High School     1186111
# 99                              New Canaan High School     0906111
# 36                              Connecticut IB Academy     0436311
# 51                             Glastonbury High School     0546111
# 204                                   RHAM High School     2086112
# 22                                Cheshire High School     0256111
# 1                                     Avon High School     0046111
# 144                               Simsbury High School     1286111
# 48                       Fairfield Ludlowe High School     0516011
# 206                            Joel Barlow High School     2096112
# 197                         Amity Regional High School     2056112
# 49                         Fairfield Warde High School     0516211
# 211                    Coginchaug Regional High School     2136112
# 145                                 Somers High School     1296111
# 57                                Guilford High School     0606111
# 130                    Old Saybrook Senior High School     1066111
# 213                     Pomperaug Regional High School     2156212
# 50                              Farmington High School     0526111
# 118                                Newtown High School     0976111
# 120                         North Branford High School     0996111
# 163                               Trumbull High School     1446111
# 2                                   Berlin High School     0076111
# 8                                   Bolton High School     0126111
# 54                               Greenwich High School     0576111
# 151              The Academy of Information Technology     1356411
# ..                                                 ...         ...
# 270                Howell Cheney Technical High School     9001616
# 132                             Plainfield High School     1096111
# 104  Hyde School of Health, Science and Sports Medi...     0936811
# 220                          Great Path Academy at MCC     2416314
# 274                        Vinal Technical High School     9001816
# 68                                   High School, Inc.     0647611
# 64    HPHS Academy of Engineering and Green Technology     0647211
# 66                     HPHS Law and Government Academy     0647411
# 112                           Wilbur Cross High School     0936111
# 74                                  Weaver High School     0646311
# 115                             New London High School     0956111
# 272               Oliver Wolcott Technical High School     9002216
# 59                                Bulkeley High School     0647111
# 261                 A. I. Prince Technical High School     9001516
# 175                                  Wilby High School     1516311
# 266               Emmett O'Brien Technical High School     9002516
# 10                                 Bassick High School     0156111
# 243                          Common Ground High School     2686113
# 271                      Norwich Technical High School     9002016
# 69          Journalism and Media Academy Magnet School     0647711
# 268                  H. H. Ellis Technical High School     9001316
# 264                  Eli Whitney Technical High School     9001416
# 65          HPHS Academy of Nursing and Health Science     0647511
# 265  Ella T. Grasso Southeastern Technical High School     9002716
# 106                      Metropolitan Business Academy     0936011
# 227                              Public Safety Academy     2415214
# 62                               Culinary Arts Academy     0646011
# 285          Three Rivers Middle College Magnet School     2456214
# 263                E. C. Goodwin Technical High School     9001916
# 38                       Stevens Alternate High school     0436411
#
#      2009_10_entrance_pct  2009_10_persistence_pct  2010_11_entrance_pct  \
# 185                  88.8                     97.8                  87.5
# 30                   83.2                     94.3                  81.6
# 188                  85.8                     96.6                  87.5
# 186                  84.4                     96.7                  79.0
# 80                   83.9                     93.7                  85.7
# 139                  87.2                     96.3                  86.0
# 99                   81.0                     94.0                  78.8
# 36                   82.1                     95.7                  81.8
# 51                   84.6                     94.9                  83.9
# 204                  83.6                     96.1                  84.7
# 22                   86.9                     95.0                  89.0
# 1                    81.8                     96.9                  84.3
# 144                  85.0                     93.5                  80.6
# 48                   85.1                     95.0                  81.6
# 206                  85.7                     92.4                  81.1
# 197                  87.1                     96.2                  83.1
# 49                   82.0                     91.4                  81.3
# 211                  89.0                     94.6                  88.5
# 145                  81.7                     94.4                  78.3
# 57                   86.8                     94.2                  82.1
# 130                  84.0                     94.0                  88.5
# 213                  86.3                     93.6                  82.8
# 50                   82.8                     93.0                  84.0
# 118                  83.0                     93.4                  85.4
# 120                  81.6                     94.2                  79.7
# 163                  85.1                     93.2                  82.9
# 2                    75.7                     94.4                  83.5
# 8                    86.4                     93.0                  88.2
# 54                   76.5                     92.8                  78.9
# 151                  75.4                     86.7                  84.3
# ..                    ...                      ...                   ...
# 270                  41.7                     67.9                  42.9
# 132                  61.6                     80.3                  57.4
# 104                  69.4                     76.0                  66.7
# 220                  77.3                     72.4                  68.2
# 274                  34.7                     74.4                  33.6
# 68                    NaN                      NaN                   NaN
# 64                   45.1                     48.8                  44.3
# 66                   49.3                     84.8                  58.5
# 112                  56.8                     73.7                  51.8
# 74                   48.2                     79.1                  39.7
# 115                  52.6                     67.5                  56.5
# 272                  47.8                     79.3                  42.7
# 59                   50.8                     72.4                  49.4
# 261                  55.2                     71.6                  54.3
# 175                  48.8                     75.4                  46.6
# 266                  35.2                     71.1                  45.1
# 10                   52.8                     68.9                  45.1
# 243                  65.5                      NaN                  51.4
# 271                  40.4                     71.1                  39.1
# 69                    NaN                      NaN                   NaN
# 268                  29.4                     75.7                  33.9
# 264                  36.9                     80.6                  46.0
# 65                   52.0                     64.2                  50.9
# 265                  47.7                     66.7                  37.5
# 106                  65.5                      NaN                  62.5
# 227                   NaN                      NaN                   NaN
# 62                   45.1                     65.6                  41.0
# 285                   NaN                      NaN                   NaN
# 263                  41.0                     55.9                  36.0
# 38                   24.6                      NaN                  23.9
#
#      2010_11_persistence_pct  2011_12_entrance_pct  2011_12_persistence_pct  \
# 185                     97.0                  86.2                     93.2
# 30                      96.1                  86.6                     97.3
# 188                     96.6                  89.4                     97.1
# 186                     96.2                  85.5                     96.4
# 80                      96.2                  88.7                     96.5
# 139                     95.0                  88.9                     94.6
# 99                      95.9                  86.7                     95.7
# 36                      85.2                 100.0                    100.0
# 51                      96.2                  88.1                     95.2
# 204                     93.3                  86.4                     93.8
# 22                      94.6                  88.7                     95.2
# 1                       95.2                  86.4                     95.0
# 144                     95.7                  82.3                     94.5
# 48                      96.0                  85.2                     91.3
# 206                     93.0                  82.9                     94.8
# 197                     94.7                  83.2                     93.4
# 49                      93.2                  83.2                     94.8
# 211                     94.8                  77.7                     89.8
# 145                     92.6                  78.8                     95.4
# 57                      91.5                  78.4                     92.3
# 130                     96.0                  82.6                     95.6
# 213                     94.4                  83.1                     94.7
# 50                      94.0                  84.8                     93.5
# 118                     90.9                  83.3                     93.6
# 120                     93.3                  80.1                     94.2
# 163                     93.2                  86.8                     94.8
# 2                       92.3                  81.7                     93.2
# 8                       93.3                  87.9                     93.1
# 54                      93.1                  76.8                     95.0
# 151                     92.9                  82.8                     89.6
# ..                       ...                   ...                      ...
# 270                     86.0                  40.7                     71.9
# 132                     84.2                  51.9                     75.0
# 104                     90.9                  57.1                     75.0
# 220                     74.7                  73.8                     79.2
# 274                     71.4                  35.2                     77.3
# 68                       NaN                  64.0                      NaN
# 64                      79.1                  34.4                     75.8
# 66                      75.0                  61.4                     74.1
# 112                     65.7                  53.4                     76.1
# 74                      67.3                   NaN                      NaN
# 115                     79.0                  63.9                     68.9
# 272                     71.1                  40.6                     72.3
# 59                      70.6                  47.4                     68.7
# 261                     69.7                  55.1                     74.4
# 175                     71.6                  43.9                     68.5
# 266                     74.5                  43.1                     67.9
# 10                      71.3                  44.9                     77.5
# 243                      NaN                  66.7                     60.0
# 271                     72.1                  33.8                     68.0
# 69                       NaN                  45.9                     70.6
# 268                     69.2                  28.6                     69.4
# 264                     71.7                  56.5                     64.6
# 65                      67.3                  49.5                     71.7
# 265                     66.7                  36.3                     71.7
# 106                     60.0                  75.7                     64.3
# 227                      NaN                   NaN                      NaN
# 62                      64.0                  26.7                      NaN
# 285                      NaN                   NaN                      NaN
# 263                     75.0                  41.3                     54.0
# 38                       NaN                  19.4                      NaN
#
#      2012_13_entrance_pct  2012_13_persistence_pct  2013_14_entrance_pct  \
# 185                  90.1                     97.3                  90.9
# 30                   90.2                     97.8                  89.3
# 188                  85.8                     96.7                  87.7
# 186                  88.5                     97.3                  90.8
# 80                   86.8                     96.8                  88.2
# 139                  87.9                     96.3                  88.5
# 99                   87.0                     96.9                  87.8
# 36                   94.6                    100.0                  95.6
# 51                   88.0                     96.2                  85.6
# 204                  79.3                     95.3                  83.2
# 22                   85.9                     95.4                  84.7
# 1                    86.8                     94.2                  88.2
# 144                  86.3                     95.0                  86.8
# 48                   84.3                     94.9                  83.3
# 206                  87.1                     95.4                  86.1
# 197                  88.0                     94.3                  86.5
# 49                   86.2                     94.7                  81.6
# 211                  86.0                     87.8                  83.7
# 145                  81.9                     94.1                  81.4
# 57                   86.3                     94.7                  86.6
# 130                  84.2                     90.2                  81.3
# 213                  81.8                     93.7                  82.6
# 50                   87.8                     94.9                  85.4
# 118                  85.1                     91.9                  85.5
# 120                  79.9                     93.1                  73.2
# 163                  84.8                     92.9                  87.0
# 2                    82.5                     95.8                  88.1
# 8                    88.8                     94.4                  84.4
# 54                   83.2                     94.6                  81.5
# 151                  85.3                     96.4                  85.4
# ..                    ...                      ...                   ...
# 270                  49.7                     79.3                  50.3
# 132                  48.0                     75.6                  67.1
# 104                  61.3                      NaN                  71.4
# 220                   NaN                      NaN                   NaN
# 274                  43.6                     72.4                  40.7
# 68                   72.5                     67.2                  50.0
# 64                   34.4                     74.2                  47.6
# 66                   49.1                     74.1                  47.2
# 112                  54.3                     75.6                  54.2
# 74                    NaN                      NaN                   NaN
# 115                  56.4                     75.2                  57.8
# 272                  43.0                     71.8                  47.1
# 59                   44.7                     72.2                  31.6
# 261                  52.6                     76.3                  60.1
# 175                  46.7                     73.9                  52.7
# 266                  41.7                     87.5                  46.3
# 10                   50.9                     67.6                  41.7
# 243                  62.9                     81.8                  65.5
# 271                  42.1                     62.5                  43.0
# 69                   53.8                     78.6                  50.0
# 268                  34.5                     59.0                  27.1
# 264                  33.0                     48.5                  32.4
# 65                   53.8                     77.2                  56.3
# 265                  43.1                     77.4                  40.2
# 106                  60.0                     77.1                  68.6
# 227                   NaN                      NaN                  73.7
# 62                   41.3                      NaN                  34.7
# 285                   NaN                      NaN                  67.7
# 263                  45.2                     66.1                  46.4
# 38                   27.2                     28.0                  20.8
#
#      2013_14_persistence_pct group   drg  four_y_percent
# 185                     96.9   all     A           97.00
# 30                      96.9   all     A           96.90
# 188                     96.9   all     A           96.70
# 186                     96.5   all     A           96.50
# 80                      96.4   all     B           96.40
# 139                     97.0   all     A           96.30
# 99                      94.9   all     A           95.70
# 36                      95.3   all     H           95.70
# 51                      95.0   all     B           95.20
# 204                     95.2   all     C           95.20
# 22                      93.9   all     B           95.00
# 1                       95.0   all     B           95.00
# 144                     96.1   all     B           95.00
# 48                      93.2   all     B           94.90
# 206                     95.7   all     A           94.80
# 197                     95.5   all     B           94.70
# 49                      96.8   all     B           94.70
# 211                     95.4   all     C           94.60
# 145                     98.1   all     C           94.40
# 57                      94.4   all     B           94.20
# 130                     92.3   all     D           94.00
# 213                     91.1   all     B           93.70
# 50                      91.6   all     B           93.50
# 118                     95.2   all     B           93.40
# 120                     87.1   all     E           93.30
# 163                     93.4   all     B           93.20
# 2                       92.0   all     D           93.20
# 8                       92.6   all     C           93.10
# 54                      90.1   all     B           93.10
# 151                     92.9   all     H           92.90
# ..                       ...   ...   ...             ...
# 270                     75.6   all  None           75.60
# 132                     75.5   all     G           75.60
# 104                     60.0   all     I           75.50
# 220                      NaN   all  None           74.70
# 274                     76.4   all  None           74.40
# 68                      81.5   all     I           74.35
# 64                      60.0   all     I           74.20
# 66                      68.0   all     I           74.10
# 112                     71.1   all     I           73.70
# 74                       NaN   all     I           73.20
# 115                     73.1   all     I           73.10
# 272                     81.8   all  None           72.30
# 59                      75.0   all     I           72.20
# 261                     62.6   all  None           71.60
# 175                     63.0   all     I           71.60
# 266                     70.2   all  None           71.10
# 10                      71.0   all     I           71.00
# 243                      NaN   all  None           70.90
# 271                     70.8   all  None           70.80
# 69                      57.1   all     I           70.60
# 268                     72.4   all  None           69.40
# 264                     67.6   all  None           67.60
# 65                      59.3   all     I           67.30
# 265                     65.3   all  None           66.70
# 106                     67.8   all     I           66.05
# 227                     64.3   all  None           64.30
# 62                      38.5   all     I           64.00
# 285                     61.9   all  None           61.90
# 263                     57.8   all  None           57.80
# 38                       NaN   all     H           28.00
#
# [191 rows x 17 columns]

# %%
def schools_df():
    all_df = get_df("all")
    all_df["race_ethnicity"] = "All"
    
    race_df = get_df("race")
    
    return pd.concat([race_df, all_df])

schools_df().to_csv("../clean/for_db/college_pers.csv",index=False)

# %%
def drg_report(df,groups=[]):
    
    ret  = df.copy()
    
    ret = ret.groupby(["drg"] + groups).agg({
            "four_y_percent":np.nanmedian
        }).reset_index()
    
    return ret

drg_report(schools_df(),groups=["race_ethnicity"]).to_csv("../clean/for_db/drg_college_pers.csv",index=False)

# %%
drg_report(get_df("race"),groups=["race_ethnicity"])
# Out:
#    drg             race_ethnicity  four_y_percent
# 0    A                      White           96.60
# 1    B                      Asian           96.90
# 2    B  Black or African American           91.30
# 3    B         Hispanic or Latino           88.60
# 4    B                      White           94.40
# 5    C                      White           92.40
# 6    D  Black or African American           81.30
# 7    D         Hispanic or Latino           82.90
# 8    D                      White           91.15
# 9    E                      White           89.90
# 10   F                      White           86.50
# 11   G  Black or African American           80.15
# 12   G         Hispanic or Latino           84.75
# 13   G                      White           87.85
# 14   H  Black or African American           82.10
# 15   H         Hispanic or Latino           82.90
# 16   H                      White           90.60
# 17   I  Black or African American           76.40
# 18   I         Hispanic or Latino           72.10
# 19   I                      White           87.40

# %%
def state_report(df,groups=[]):
    
    ret  = df.copy()
    
    if len(groups) > 0:
        ret = ret.groupby(groups).agg({
                "four_y_percent":np.nanmedian
        }).reset_index()
    
    
    
    return ret#["four_y_percent"].median
state_report(schools_df(),groups=["race_ethnicity"]).to_csv("../clean/for_db/state_college_pers.csv",index=False)
#state_report(get_df("race"),groups=["race_ethnicity"])

# %%
def full_df():
    
    school_race_df = get_df("race")
    school_all_df = get_df("all")
    school_all_df["race_ethnicity"] = "All"
    
    df = pd.concat([school_race_df,school_all_df])
    
    drg_df = drg_report(df,groups=["race_ethnicity"])
    
    state_df = state_report(df,groups=["race_ethnicity"])
    
    def drg_val(row):
        matches = drg_df[(drg_df["drg"] == row["drg"]) & (drg_df["race_ethnicity"] == row["race_ethnicity"])]
        if len(matches) != 1:
            return None
        
        #print matches.iloc[0]
        return matches.iloc[0]["four_y_percent"]
        
    def state_val(row):
        matches = state_df[state_df["race_ethnicity"] == row["race_ethnicity"]]
        if len(matches) != 1:
            return None
        
        #print matches.iloc[0]
        return matches.iloc[0]["four_y_percent"]

    df["drg_4y"] = df.apply(drg_val, axis=1)
    df["state_4y"] = df.apply(state_val, axis=1)

    
    df = df[["district_code","district","school_code","school",
             "race_ethnicity","four_y_percent","drg_4y","state_4y"]]
    
    df.columns = ["district_code","district","school_code","school",
             "race","school_rate","drg_rate","state_rate"]
    return df

full_df()#.sort_values(by="school")
# Out:
#     district_code                                           district  \
# 2         0020011                            Ansonia School District
# 3         0020011                            Ansonia School District
# 6         0020011                            Ansonia School District
# 12        0040011                               Avon School District
# 18        0070011                             Berlin School District
# 24        0090011                             Bethel School District
# 27        0110011                         Bloomfield School District
# 46        0120011                             Bolton School District
# 52        0140011                           Branford School District
# 55        0150011                         Bridgeport School District
# 56        0150011                         Bridgeport School District
# 59        0150011                         Bridgeport School District
# 61        0150011                         Bridgeport School District
# 62        0150011                         Bridgeport School District
# 65        0150011                         Bridgeport School District
# 68        0150011                         Bridgeport School District
# 69        0150011                         Bridgeport School District
# 80        0170011                            Bristol School District
# 82        0170011                            Bristol School District
# 86        0170011                            Bristol School District
# 88        0170011                            Bristol School District
# 97        0180011                         Brookfield School District
# 102       0230011                             Canton School District
# 104       0250011                           Cheshire School District
# 107       0250011                           Cheshire School District
# 116       0270011                            Clinton School District
# 122       0280011                         Colchester School District
# 127       0320011                           Coventry School District
# 134       0330011                           Cromwell School District
# 140       0340011                            Danbury School District
# ..            ...                                                ...
# 220       2410014                   Capitol Region Education Council
# 221       2410014                   Capitol Region Education Council
# 225       2410014                   Capitol Region Education Council
# 226       2410014                   Capitol Region Education Council
# 227       2410014                   Capitol Region Education Council
# 240       2530014  Eastern Connecticut Regional Educational Servi...
# 243       2680013                 Common Ground High School District
# 244       2690013                        The Bridge Academy District
# 246       2790013                           Amistad Academy District
# 261       9000016           Connecticut Technical High School System
# 262       9000016           Connecticut Technical High School System
# 263       9000016           Connecticut Technical High School System
# 264       9000016           Connecticut Technical High School System
# 265       9000016           Connecticut Technical High School System
# 266       9000016           Connecticut Technical High School System
# 267       9000016           Connecticut Technical High School System
# 268       9000016           Connecticut Technical High School System
# 269       9000016           Connecticut Technical High School System
# 270       9000016           Connecticut Technical High School System
# 271       9000016           Connecticut Technical High School System
# 272       9000016           Connecticut Technical High School System
# 273       9000016           Connecticut Technical High School System
# 274       9000016           Connecticut Technical High School System
# 275       9000016           Connecticut Technical High School System
# 276       9000016           Connecticut Technical High School System
# 277       9010022                      Norwich Free Academy District
# 278       9020022                        The Gilbert School District
# 279       9030022                         Woodstock Academy District
# 282       2450014                                              Learn
# 285       2450014                                              Learn
#
#     school_code                                             school  \
# 2       0026111                                Ansonia High School
# 3       0026111                                Ansonia High School
# 6       0026111                                Ansonia High School
# 12      0046111                                   Avon High School
# 18      0076111                                 Berlin High School
# 24      0096111                                 Bethel High School
# 27      0116111                             Bloomfield High School
# 46      0126111                                 Bolton High School
# 52      0146111                               Branford High School
# 55      0156111                                Bassick High School
# 56      0156111                                Bassick High School
# 59      0156211                                Central High School
# 61      0156211                                Central High School
# 62      0156211                                Central High School
# 65      0156211                                Central High School
# 68      0156311                                Harding High School
# 69      0156311                                Harding High School
# 80      0176111                        Bristol Central High School
# 82      0176111                        Bristol Central High School
# 86      0176211                        Bristol Eastern High School
# 88      0176211                        Bristol Eastern High School
# 97      0186111                             Brookfield High School
# 102     0236111                                 Canton High School
# 104     0256111                               Cheshire High School
# 107     0256111                               Cheshire High School
# 116     0276111                                  The Morgan School
# 122     0286111                                      Bacon Academy
# 127     0326111                               Coventry High School
# 134     0336111                               Cromwell High School
# 140     0346111                                Danbury High School
# ..          ...                                                ...
# 220     2416314                          Great Path Academy at MCC
# 221     2416414  Greater Hartford Academy of  the Arts High Sch...
# 225     2416514  Medical Professions and Teacher Preparation Ac...
# 226     2416114  Metropolitan Learning Center for Global and In...
# 227     2415214                              Public Safety Academy
# 240     2536014    Arts at the Capitol Theater Magnet School (ACT)
# 243     2686113                          Common Ground High School
# 244     2696113                                 The Bridge Academy
# 246     2795113                                    Amistad Academy
# 261     9001516                 A. I. Prince Technical High School
# 262     9001116               Bullard-Havens Technical High School
# 263     9001916                E. C. Goodwin Technical High School
# 264     9001416                  Eli Whitney Technical High School
# 265     9002716  Ella T. Grasso Southeastern Technical High School
# 266     9002516               Emmett O'Brien Technical High School
# 267     9001716                 H. C. Wilcox Technical High School
# 268     9001316                  H. H. Ellis Technical High School
# 269     9001216                 Henry Abbott Technical High School
# 270     9001616                Howell Cheney Technical High School
# 271     9002016                      Norwich Technical High School
# 272     9002216               Oliver Wolcott Technical High School
# 273     9002616                        Platt Technical High School
# 274     9001816                        Vinal Technical High School
# 275     9002316                 W. F. Kaynor Technical High School
# 276     9002416                      Windham Technical High School
# 277     9016122                               Norwich Free Academy
# 278     9026122                                 The Gilbert School
# 279     9036122                                  Woodstock Academy
# 282     2456014                          Connecticut River Academy
# 285     2456214          Three Rivers Middle College Magnet School
#
#                                  race  school_rate  drg_rate  state_rate
# 2           Black or African American        78.30    81.600      78.800
# 3                  Hispanic or Latino        63.60    82.900      79.500
# 6                               White        90.70    90.600      90.525
# 12                              White        95.40    94.400      90.525
# 18                              White        94.00    91.150      90.525
# 24                              White        91.10    91.150      90.525
# 27          Black or African American        82.50    81.725      78.800
# 46                              White        93.20    92.400      90.525
# 52                              White        91.20    91.150      90.525
# 55          Black or African American        75.40    75.900      78.800
# 56                 Hispanic or Latino        73.30    72.100      79.500
# 59   American Indian or Alaska Native        86.25    86.250      86.250
# 61          Black or African American        84.70    75.900      78.800
# 62                 Hispanic or Latino        79.20    72.100      79.500
# 65                              White        87.50    87.500      90.525
# 68          Black or African American        75.00    75.900      78.800
# 69                 Hispanic or Latino        78.60    72.100      79.500
# 80                 Hispanic or Latino        86.20    80.900      79.500
# 82                              White        90.30    87.800      90.525
# 86                 Hispanic or Latino        80.00    80.900      79.500
# 88                              White        87.90    87.800      90.525
# 97                              White        91.60    94.400      90.525
# 102                             White        91.80    92.400      90.525
# 104                             Asian       100.00    96.000      95.200
# 107                             White        94.90    94.400      90.525
# 116                             White        91.70    91.150      90.525
# 122                             White        89.20    91.150      90.525
# 127                             White        89.90    89.100      90.525
# 134                             White        90.90    91.150      90.525
# 140                             Asian        95.40    93.325      95.200
# ..                                ...          ...       ...         ...
# 220                               All        74.70       NaN      87.900
# 221                               All        80.05       NaN      87.900
# 225                               All        85.70       NaN      87.900
# 226                               All        86.60       NaN      87.900
# 227                               All        64.30       NaN      87.900
# 240                               All        76.65       NaN      87.900
# 243                               All        70.90       NaN      87.900
# 244                               All        79.15       NaN      87.900
# 246                               All        85.00       NaN      87.900
# 261                               All        71.60       NaN      87.900
# 262                               All        81.70       NaN      87.900
# 263                               All        57.80       NaN      87.900
# 264                               All        67.60       NaN      87.900
# 265                               All        66.70       NaN      87.900
# 266                               All        71.10       NaN      87.900
# 267                               All        77.30       NaN      87.900
# 268                               All        69.40       NaN      87.900
# 269                               All        78.10       NaN      87.900
# 270                               All        75.60       NaN      87.900
# 271                               All        70.80       NaN      87.900
# 272                               All        72.30       NaN      87.900
# 273                               All        84.90       NaN      87.900
# 274                               All        74.40       NaN      87.900
# 275                               All        82.40       NaN      87.900
# 276                               All        76.30       NaN      87.900
# 277                               All        86.90    86.450      87.900
# 278                               All        78.80    86.450      87.900
# 279                               All        90.10    88.900      87.900
# 282                               All        84.10       NaN      87.900
# 285                               All        61.90       NaN      87.900
#
# [504 rows x 8 columns]

# %%
full_df().to_csv("../clean/for_db/college_pers.csv",index=False)
